# %%
from collections import defaultdict

from gensim import models
from nltk import word_tokenize
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import json

# %%
def load_graph(path='/kaggle/input/feed-data/graph.txt'):
    graph = defaultdict(list)
    with open(path, 'r') as f:
        for line in f:
            src, rel, dst = eval(line.strip())
            graph[src].append((rel, dst))
    return graph

# %%
def load_queries(path='/kaggle/input/feed-data/questions.txt'):
    queries = []
    with open(path, 'r') as f:
        for line in f:
            qid, question, start_node, _, _, answers = eval(line.strip())
            answer_ids = {ans['AnswerArgument'] for ans in answers}
            queries.append({
                'qid': qid,
                'question': question,
                'start_node': start_node,
                'answers': answer_ids
            })
    return queries

# %%
import json

def load_vertex_lookup(path='/kaggle/input/feed-data/mapping.json'):
    with open(path, 'r') as f:
        return json.load(f)

# %%
from gensim import models
from nltk import word_tokenize
import numpy as np

word2vec_model = models.Word2Vec.load('/kaggle/input/word-vector/word2vec_train_dev.dat')


def get_rel_score_word2vecbase(rel: str, query: str) -> float:
    """
    Get score for query and relation. Used to inform exploration of knowledge graph.

    :param rel: relation, or edge in knowledge graph
    :param query: query, question to answer
    :return: float score similarity between question and relation
    """
    # Relation not in embedding vocabulary
    rel = 'ns:' + rel if not rel[:3] == 'ns:' else rel
    if rel not in word2vec_model.wv:
        return 0.0
    # Relation must start with ns:
    

    words = word_tokenize(query.lower())
    w_embs = []
    for w in words:
        if w in word2vec_model.wv:
            w_embs.append(word2vec_model.wv[w])
    return np.mean(cosine_similarity(w_embs, [word2vec_model.wv[rel]]))

# %%
import numpy as np
from collections import deque
from sklearn.metrics import f1_score

def traverse_graph(graph, query, start_node, max_depth=2, score_threshold=0.25):
    visited = set()
    answers = set()
    queue = deque([(start_node, 0)])

    while queue:
        current_node, depth = queue.popleft()
        if depth > max_depth:
            continue
        visited.add(current_node)
        for rel, neighbor in graph.get(current_node, []):
            if neighbor in visited:
                continue
            score = get_rel_score_word2vecbase(rel, query)
            if score >= score_threshold:
                answers.add(neighbor)
                queue.append((neighbor, depth + 1))
    return answers

# %%
def evaluate_all_queries(graph, queries):
    f1s = []
    for q in queries:
        predicted = traverse_graph(graph, q['question'], q['start_node'])
        true = q['answers']
        all_ids = list(predicted.union(true))
        y_true = [1 if x in true else 0 for x in all_ids]
        y_pred = [1 if x in predicted else 0 for x in all_ids]
        score = f1_score(y_true, y_pred)
        print(f"Q{q['qid']}: {q['question']}\nF1: {score:.2f}\n")
        f1s.append(score)
    print(f"\nAverage F1 across all queries: {np.mean(f1s):.3f}")

# %%
if __name__ == "__main__":
    graph = load_graph()
    queries = load_queries()
    vertex_lookup = load_vertex_lookup()
    
    evaluate_all_queries(graph, queries)
# Out:
# Q1: what time zones are there in the us
# F1: 0.12
#
# Q2: what are major exports of the usa
# F1: 0.24
#
# Q3: what time is right now in texas
# F1: 0.03
#
# Q4: what war was george washington associated with
# F1: 0.45
#
# Q5: what are the most common religions in the united states
# F1: 0.44
#
# Q6: what are the names of michael jackson children
# F1: 0.10
#
# Q7: when michael jordan got drafted
# F1: 0.25
#
# Q8: what type of government and economic system does the united states have
# F1: 0.38
#
# Q9: what country was george washington from
# F1: 0.07
#
# Q10: what are the major imports of the united states
# F1: 0.12
#
# Q11: on which continent is the usa located
# F1: 0.07
#
# Q12: what continent is the usa located in
# F1: 0.01
#
# Q13: what are the airports in chicago
# F1: 0.14
#
# Q14: what are the names of michael jackson movies
# F1: 0.09
#
# Q15: what timezone is illinois on
# F1: 0.02
#
# Q16: what year michael jordan came in the nba
# F1: 0.25
#
# Q17: what is the political system of the us
# F1: 0.27
#
# Q18: what illnesses did george washington have
# F1: 0.18
#
# Q19: what illnesses did george washington suffer from
# F1: 0.18
#
# Q20: where is south carolina located
# F1: 0.01
#
# Q21: what kind of government does the united states have today
# F1: 0.60
#
# Q22: who were michael jackson 's brothers and sisters
# F1: 0.03
#
# Q23: what is zip code for chicago illinois
# F1: 0.84
#
# Q24: what kind of system of government does the united states have
# F1: 0.38
#
# Q25: what type of currency does the us have
# F1: 0.40
#
# Q26: what are all of michael jackson albums
# F1: 0.22
#
# Q27: what year did michael jordan started his career
# F1: 0.25
#
# Q28: what year was michael jordan rookie year
# F1: 0.25
#
# Q29: what timezone is the state of texas
# F1: 0.03
#
# Q30: what was basketball player michael jordan 's major in college
# F1: 0.25
#
# Q31: what all did michael jackson own
# F1: 0.04
#
# Q32: what system of government is used in the united states of america
# F1: 0.12
#
# Q33: what products are made in the usa
# F1: 0.00
#
# Q34: what type of government is the us government
# F1: 0.19
#
# Q35: what is george washington 's hometown
# F1: 0.00
#
# Q36: where to hang out in chicago
# F1: 0.34
#
# Q37: what school did michael jordan go to
# F1: 0.44
#
# Q38: what disease michael jackson
# F1: 0.03
#
# Q39: what is the capital city of south carolina
# F1: 0.02
#
# Q40: what does michael jackson like to eat
# F1: 0.04
#
# Q41: what times is it in texas
# F1: 0.03
#
# Q42: what kind of music did michael jackson sing
# F1: 0.25
#
# Q43: what are major religions in the united states
# F1: 0.34
#
# Q44: what war did george washington help win
# F1: 0.44
#
# Q45: what war was george washington president during
# F1: 0.44
#
# Q46: what school did michael jackson attend
# F1: 0.03
#
# Q47: what was the cause of death of michael jackson
# F1: 0.03
#
# Q48: what is the capital city of texas usa
# F1: 0.02
#
# Q49: who influenced michael jackson
# F1: 0.15
#
# Q50: what zip code is chicago il
# F1: 0.78
#
# Q51: what state in chicago in
# F1: 0.02
#
# Q52: where was george washington originally from
# F1: 0.00
#
# Q53: where did michael jackson went to school
# F1: 0.12
#
# Q54: what year did michael jordan get drafted
# F1: 0.25
#
# Q56: what form of government do we have in the usa
# F1: 0.46
#
# Q57: what kind government does the us have
# F1: 0.86
#
#
# Average F1 across all queries: 0.216
